# %% [markdown]
# ## 神经网络
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 常规套路
# * 1.收集数据并给定标签
# * 2.训练一个分类器
# * 3.测试，评估
#
# ### 数据集样例：CIFAR-10
#
# ### 计算机视觉所面临的问题
# * 照射角度
# * 光照强度
# * 形状的改变
# * 部分遮蔽
# * 背景混入
